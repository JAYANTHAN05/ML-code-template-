# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
dataset=pd.read_csv("Mall_Customers.csv")
x=dataset.iloc[:,[3,4]].values

# %%
#using dendrogram to find the optimal no of clusters
from scipy.cluster import hierarchy as sch #ScipyClusterHierarchy
dendrogram  = sch.dendrogram(sch.linkage(x,method='ward')) #it take 2 parameter one is method and another one is linking with which data
plt.title("Dendrogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean distance")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=5, linkage='ward')
y_hc = hc.fit_predict(x)
